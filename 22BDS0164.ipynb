# %% [markdown]
# <a href="https://colab.research.google.com/github/garvit3434/EDA_PROJECT_22BDS0164/blob/main/22BDS0164.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#22BDS0164
#GARVIT JUNEJA
#DATASET LINK : https://raw.githubusercontent.com/salemprakash/EDA/main/Data/KosteckiDillon.csv




#Module 2


import pandas as pd
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/KosteckiDillon.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    rownames  id  time  dos hatype  age  airq  medication headache     sex
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
# 3         4   1    -8  756   Aura   30  13.0  continuing      yes  female
# 4         5   1    -7  757   Aura   30  18.0  continuing      yes  female

# %%
#Dimensions and statistics

print(df.shape)
# Out:
# (4152, 10)

# %%
print(len(df))
# Out:
# 4152

# %%
print(len(df.columns))
# Out:
# 10

# %%
print(df.columns.size)
# Out:
# 10

# %%
print(df.axes)
print(len(df.axes[0]))
print(len(df.axes[1]))
# Out:
# [RangeIndex(start=0, stop=4152, step=1), Index(['rownames', 'id', 'time', 'dos', 'hatype', 'age', 'airq', 'medication',
#        'headache', 'sex'],
#       dtype='object')]
# 4152
# 10

# %%
print(df.count())
print(df.count().max())
# Out:
# rownames      4152
# id            4152
# time          4152
# dos           4152
# hatype        4152
# age           4152
# airq          4152
# medication    4152
# headache      4152
# sex           4152
# dtype: int64
# 4152

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4152 entries, 0 to 4151
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rownames    4152 non-null   int64
#  1   id          4152 non-null   int64
#  2   time        4152 non-null   int64
#  3   dos         4152 non-null   int64
#  4   hatype      4152 non-null   object
#  5   age         4152 non-null   int64
#  6   airq        4152 non-null   float64
#  7   medication  4152 non-null   object
#  8   headache    4152 non-null   object
#  9   sex         4152 non-null   object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 324.5+ KB

# %%
import numpy as np
print(np.shape(df))
# Out:
# (4152, 10)

# %%
#Data Transformation

dataFrame1 = df.iloc[:len(df)//2]
dataFrame2 = df.iloc[len(df)//2:]

print("First DataFrame:\n", dataFrame1.head(), "\n")
print("Second DataFrame:\n", dataFrame2.head(), "\n")
# Out:
# First DataFrame:
#     rownames  id  time  dos hatype  age  airq  medication headache     sex
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
# 3         4   1    -8  756   Aura   30  13.0  continuing      yes  female
# 4         5   1    -7  757   Aura   30  18.0  continuing      yes  female
#
# Second DataFrame:
#        rownames  id  time  dos   hatype  age  airq  medication headache     sex
# 2076      2077  67   -22  560  No Aura   46  29.0  continuing      yes  female
# 2077      2078  67   -21  561  No Aura   46  14.0  continuing      yes  female
# 2078      2079  67   -20  562  No Aura   46  33.0  continuing      yes  female
# 2079      2080  67   -19  563  No Aura   46  37.0  continuing      yes  female
# 2080      2081  67   -18  564  No Aura   46  36.0  continuing      yes  female

# %%
dataframe = pd.concat([dataFrame1, dataFrame2], ignore_index=True)
dataframe
# Out:
#       rownames   id  time   dos hatype  age  airq  medication headache     sex
# 0            1    1   -11   753   Aura   30   9.0  continuing      yes  female
# 1            2    1   -10   754   Aura   30   7.0  continuing      yes  female
# 2            3    1    -9   755   Aura   30  10.0  continuing      yes  female
# 3            4    1    -8   756   Aura   30  13.0  continuing      yes  female
# 4            5    1    -7   757   Aura   30  18.0  continuing      yes  female
# ...        ...  ...   ...   ...    ...  ...   ...         ...      ...     ...
# 4147      4148  133    44  1232   Aura   26  20.0  continuing      yes    male
# 4148      4149  133    45  1233   Aura   26  27.0  continuing       no    male
# 4149      4150  133    46  1234   Aura   26  28.0  continuing       no    male
# 4150      4151  133    47  1235   Aura   26  33.0  continuing       no    male
# 4151      4152  133    48  1236   Aura   26  25.0  continuing      yes    male
#
# ...

# %%
pd.concat([dataFrame1, dataFrame2], axis=1)
# Out:
#       rownames   id  time    dos hatype   age  airq  medication headache  \
# 0          1.0  1.0 -11.0  753.0   Aura  30.0   9.0  continuing      yes
# 1          2.0  1.0 -10.0  754.0   Aura  30.0   7.0  continuing      yes
# 2          3.0  1.0  -9.0  755.0   Aura  30.0  10.0  continuing      yes
# 3          4.0  1.0  -8.0  756.0   Aura  30.0  13.0  continuing      yes
# 4          5.0  1.0  -7.0  757.0   Aura  30.0  18.0  continuing      yes
# ...        ...  ...   ...    ...    ...   ...   ...         ...      ...
# 4147       NaN  NaN   NaN    NaN    NaN   NaN   NaN         NaN      NaN
# 4148       NaN  NaN   NaN    NaN    NaN   NaN   NaN         NaN      NaN
# 4149       NaN  NaN   NaN    NaN    NaN   NaN   NaN         NaN      NaN
# 4150       NaN  NaN   NaN    NaN    NaN   NaN   NaN         NaN      NaN
# 4151       NaN  NaN   NaN    NaN    NaN   NaN   NaN         NaN      NaN
#
#          sex  rownames     id  time     dos hatype   age  airq  medication  \
# ...

# %%
df['age_medication_product'] = df['age'] * df['medication']
df.head(10)
# Out:
#    rownames  id  time  dos hatype  age  airq  medication headache     sex  \
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
# 3         4   1    -8  756   Aura   30  13.0  continuing      yes  female
# 4         5   1    -7  757   Aura   30  18.0  continuing      yes  female
# 5         6   1    -6  758   Aura   30  19.0  continuing      yes  female
# 6         7   1    -5  759   Aura   30  17.0  continuing      yes  female
# 7         8   1    22  786   Aura   30  21.0  continuing      yes  female
# 8         9   1    23  787   Aura   30  21.0  continuing      yes  female
# 9        10   1    24  788   Aura   30  18.0  continuing      yes  female
#
#                               age_medication_product
# 0  continuingcontinuingcontinuingcontinuingcontin...
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# female    3545
# male       607
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#           rownames           id         time          dos          age  \
# count  4152.000000  4152.000000  4152.000000  4152.000000  4152.000000
# mean   2076.500000    66.386802    15.455684   646.705925    42.363921
# std    1198.723488    39.121812    21.737211   335.770123    11.201244
# min       1.000000     1.000000   -29.000000    98.000000    18.000000
# 25%    1038.750000    33.000000     3.000000   384.000000    33.000000
# 50%    2076.500000    67.000000    12.000000   623.000000    44.000000
# 75%    3114.250000   100.000000    24.000000   950.000000    50.000000
# max    4152.000000   133.000000    99.000000  1239.000000    66.000000
#
#               airq
# count  4152.000000
# mean     24.826012
# std       9.514274
# min       3.000000
# 25%      18.000000
# 50%      24.000000
# 75%      29.000000
# max      73.000000

# %%
data = df.iloc[0:3, 1:6].values
indexers = ['Row1', 'Row2', 'Row3']
columns = df.columns[1:6]

dframe1 = pd.DataFrame(data, index=indexers, columns=columns)
dframe1
# Out:
#      id time  dos hatype age
# Row1  1  -11  753   Aura  30
# Row2  1  -10  754   Aura  30
# Row3  1   -9  755   Aura  30

# %%
#Data handling
stacked = dframe1.stack()
stacked
# Out:
# Row1  id           1
#       time       -11
#       dos        753
#       hatype    Aura
#       age         30
# Row2  id           1
#       time       -10
#       dos        754
#       hatype    Aura
#       age         30
# Row3  id           1
#       time        -9
#       dos        755
#       hatype    Aura
#       age         30
# dtype: object

# %%
stacked.unstack()
# Out:
#      id time  dos hatype age
# Row1  1  -11  753   Aura  30
# Row2  1  -10  754   Aura  30
# Row3  1   -9  755   Aura  30

# %%
series1 = pd.Series(df['age'].iloc[0:4].values, index=['row1', 'row2', 'row3', 'row4'])
series2 = pd.Series(df['airq'].iloc[0:3].values, index=['row5', 'row6', 'row7'])

frame2 = pd.concat([series1, series2], keys=['Age', 'AirQuality'])
frame2.unstack()
# Out:
#             row1  row2  row3  row4  row5  row6  row7
# Age         30.0  30.0  30.0  30.0   NaN   NaN   NaN
# AirQuality   NaN   NaN   NaN   NaN   9.0   7.0  10.0

# %%
#Transformation techniques

frame3 = pd.DataFrame({
    'hatype': [df['hatype'].iloc[0]] * 3 + [df['hatype'].iloc[1]] * 4,
    'age': [df['age'].iloc[0], df['age'].iloc[0], df['age'].iloc[2],
            df['age'].iloc[3], df['age'].iloc[3], df['age'].iloc[4], df['age'].iloc[4]]
})
frame3
# Out:
#   hatype  age
# 0   Aura   30
# 1   Aura   30
# 2   Aura   30
# 3   Aura   30
# 4   Aura   30
# 5   Aura   30
# 6   Aura   30

# %%
frame3.duplicated()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
frame4 = frame3.drop_duplicates()
frame4
# Out:
#   hatype  age
# 0   Aura   30

# %%
frame3['sex'] = range(7)
frame5 = frame3.drop_duplicates(['age'])
frame5
# Out:
#   hatype  age  column 3  sex
# 0   Aura   30         0    0

# %%
replaceFrame = pd.DataFrame({
    'age': [25, 32, 45, 51, 28, 37, 42, 30, 55],
    'id': range(9)
})

replaceFrame
# Out:
#    age  id
# 0   25   0
# 1   32   1
# 2   45   2
# 3   51   3
# 4   28   4
# 5   37   5
# 6   42   6
# 7   30   7
# 8   55   8

# %%
replaceFrame = replaceFrame.replace(to_replace=-786, value=np.nan)
replaceFrame
# Out:
#    age  id
# 0   25   0
# 1   32   1
# 2   45   2
# 3   51   3
# 4   28   4
# 5   37   5
# 6   42   6
# 7   30   7
# 8   55   8

# %%
data = np.arange(15, 30).reshape(5, 3)
dfx = pd.DataFrame(
    data,
    index=['rownames1', 'rownames2', 'rownames3', 'rownames4', 'rownames5'],
    columns=['id', 'time', 'dos']
)
dfx
# Out:
#            id  time  dos
# rownames1  15    16   17
# rownames2  18    19   20
# rownames3  21    22   23
# rownames4  24    25   26
# rownames5  27    28   29

# %%
dfx.isnull()
# Out:
#               id   time    dos
# rownames1  False  False  False
# rownames2  False  False  False
# rownames3  False  False  False
# rownames4  False  False  False
# rownames5  False  False  False

# %%
dfx.notnull()
# Out:
#              id  time   dos
# rownames1  True  True  True
# rownames2  True  True  True
# rownames3  True  True  True
# rownames4  True  True  True
# rownames5  True  True  True

# %%
dfx.isnull().sum()
# Out:
# id      0
# time    0
# dos     0
# dtype: int64

# %%
dfx.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dfx.count()
# Out:
# id      5
# time    5
# dos     5
# dtype: int64

# %%
df.age[df.age.notnull()]
# Out:
# 0       30
# 1       30
# 2       30
# 3       30
# 4       30
#         ..
# 4147    26
# 4148    26
# 4149    26
# 4150    26
# 4151    26
# Name: age, Length: 4152, dtype: int64

# %%
dfx.dropna()
# Out:
#            id  time  dos
# rownames1  15    16   17
# rownames2  18    19   20
# rownames3  21    22   23
# rownames4  24    25   26
# rownames5  27    28   29

# %%
dfx.dropna(how='all')
# Out:
#            id  time  dos
# rownames1  15    16   17
# rownames2  18    19   20
# rownames3  21    22   23
# rownames4  24    25   26
# rownames5  27    28   29

# %%
dfx.dropna(how='all', axis=1)
# Out:
#            id  time  dos
# rownames1  15    16   17
# rownames2  18    19   20
# rownames3  21    22   23
# rownames4  24    25   26
# rownames5  27    28   29

# %%
df = pd.DataFrame({
    'rownames': [1, 2, 3, 4],
    'id': [101, 102, 103, 104],
    'time': [5, 10, 15, 20],
    'dos': [1, 2, 1, 3],
    'hatype': ['type1', 'type2', 'type1', 'type3'],
    'age': [25, 30, np.nan, 40],
    'airq': [100, 200, 150, 180],
    'medication': ['yes', 'no', 'yes', 'yes'],
    'headache': ['mild', 'severe', 'none', 'mild'],
    'sex': ['M', 'F', 'M', 'F']
})

numeric_cols = df.select_dtypes(include=[np.number])
numpy_means = numeric_cols.apply(lambda col: col.to_numpy().mean())
pandas_means = numeric_cols.mean()
numpy_means, pandas_means
# Out:
# (rownames      2.50
#  id          102.50
#  time         12.50
#  dos           1.75
#  age            NaN
#  airq        157.50
#  dtype: float64,
#  rownames      2.500000
#  id          102.500000
#  time         12.500000
#  dos           1.750000
#  age          31.666667
#  airq        157.500000
#  dtype: float64)

# %%
ser2 = df.age
ser2.sum()
ser2.mean()
ser2.cumsum()
# Out:
# 0    25.0
# 1    55.0
# 2     NaN
# 3    95.0
# Name: age, dtype: float64

# %%
filledDf = dfx.fillna(0)
filledDf
# Out:
#            id  time  dos
# rownames1  15    16   17
# rownames2  18    19   20
# rownames3  21    22   23
# rownames4  24    25   26
# rownames5  27    28   29

# %%
filledDf.mean()
# Out:
# id      21.0
# time    22.0
# dos     23.0
# dtype: float64

# %%
df.age.fillna(method='bfill')
# Out:
# /tmp/ipython-input-2226928627.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.age.fillna(method='bfill')
# 0    25.0
# 1    30.0
# 2    40.0
# 3    40.0
# Name: age, dtype: float64

# %%
#$Discretization and binning
bins = [10, 20, 40, 60, 100]
category = pd.cut(df.age, bins)
category
# Out:
# 0    (20.0, 40.0]
# 1    (20.0, 40.0]
# 2             NaN
# 3    (20.0, 40.0]
# Name: age, dtype: category
# Categories (4, interval[int64, right]): [(10, 20] < (20, 40] < (40, 60] < (60, 100]]

# %%
pd.value_counts(category)
# Out:
# /tmp/ipython-input-2654243906.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category)
# age
# (20, 40]     3
# (10, 20]     0
# (40, 60]     0
# (60, 100]    0
# Name: count, dtype: int64

# %%
bins = [0, 20, 40, 60, 100]
bin_names = ['Young', 'Adult', 'Middle-aged', 'Senior']
pd.cut(df['age'], bins, labels=bin_names)
# Out:
# 0    Adult
# 1    Adult
# 2      NaN
# 3    Adult
# Name: age, dtype: category
# Categories (4, object): ['Young' < 'Adult' < 'Middle-aged' < 'Senior']

# %%
pd.value_counts(pd.cut(df['age'], bins, labels=bin_names))
# Out:
# /tmp/ipython-input-2046034497.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(pd.cut(df['age'], bins, labels=bin_names))
# age
# Adult          3
# Young          0
# Middle-aged    0
# Senior         0
# Name: count, dtype: int64

# %%
pd.cut(np.random.rand(40), 5, precision=2)
# Out:
# [(0.6, 0.8], (0.8, 0.99], (0.6, 0.8], (0.014, 0.21], (0.4, 0.6], ..., (0.4, 0.6], (0.4, 0.6], (0.4, 0.6], (0.4, 0.6], (0.4, 0.6]]
# Length: 40
# Categories (5, interval[float64, right]): [(0.014, 0.21] < (0.21, 0.4] < (0.4, 0.6] < (0.6, 0.8] <
#                                            (0.8, 0.99]]

# %%
randomNumbers = np.random.rand(2000)
category3 = pd.qcut(randomNumbers, 4)
category3
# Out:
# [(-0.000576, 0.255], (0.75, 1.0], (0.75, 1.0], (0.501, 0.75], (-0.000576, 0.255], ..., (0.75, 1.0], (0.75, 1.0], (0.75, 1.0], (-0.000576, 0.255], (0.75, 1.0]]
# Length: 2000
# Categories (4, interval[float64, right]): [(-0.000576, 0.255] < (0.255, 0.501] < (0.501, 0.75] <
#                                            (0.75, 1.0]]

# %%
#
#Outlier detection and filtering
df = pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/KosteckiDillon.csv')
df.head(10)
# Out:
#    rownames  id  time  dos hatype  age  airq  medication headache     sex
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
# 3         4   1    -8  756   Aura   30  13.0  continuing      yes  female
# 4         5   1    -7  757   Aura   30  18.0  continuing      yes  female
# 5         6   1    -6  758   Aura   30  19.0  continuing      yes  female
# 6         7   1    -5  759   Aura   30  17.0  continuing      yes  female
# 7         8   1    22  786   Aura   30  21.0  continuing      yes  female
# 8         9   1    23  787   Aura   30  21.0  continuing      yes  female
# 9        10   1    24  788   Aura   30  18.0  continuing      yes  female

# %%
df['DosAgeProduct'] = df['dos'] * df['age']
df
# Out:
#       rownames   id  time   dos hatype  age  airq  medication headache  \
# 0            1    1   -11   753   Aura   30   9.0  continuing      yes
# 1            2    1   -10   754   Aura   30   7.0  continuing      yes
# 2            3    1    -9   755   Aura   30  10.0  continuing      yes
# 3            4    1    -8   756   Aura   30  13.0  continuing      yes
# 4            5    1    -7   757   Aura   30  18.0  continuing      yes
# ...        ...  ...   ...   ...    ...  ...   ...         ...      ...
# 4147      4148  133    44  1232   Aura   26  20.0  continuing      yes
# 4148      4149  133    45  1233   Aura   26  27.0  continuing       no
# 4149      4150  133    46  1234   Aura   26  28.0  continuing       no
# 4150      4151  133    47  1235   Aura   26  33.0  continuing       no
# 4151      4152  133    48  1236   Aura   26  25.0  continuing      yes
#
#          sex  DosAgeProduct
# 0     female          22590
# 1     female          22620
# ...

# %%
df['TotalTransaction'] = df['dos'] * df['age']
df['TotalTransaction'][np.abs(df['TotalTransaction']) > 100]
# Out:
# 0       22590
# 1       22620
# 2       22650
# 3       22680
# 4       22710
#         ...
# 4147    32032
# 4148    32058
# 4149    32084
# 4150    32110
# 4151    32136
# Name: TotalTransaction, Length: 4152, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2220213319.py in <cell line: 0>()
# ----> 1 df[np.abs(TotalTransaction) > 6741112]
#
# NameError: name 'TotalTransaction' is not defined

# %%
#Module 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
print(df.head(3))
print(df.tail(3))
# Out:
#    rownames  id  time  dos hatype  age  airq  medication headache     sex
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
#       rownames   id  time   dos hatype  age  airq  medication headache   sex
# 4149      4150  133    46  1234   Aura   26  28.0  continuing       no  male
# 4150      4151  133    47  1235   Aura   26  33.0  continuing       no  male
# 4151      4152  133    48  1236   Aura   26  25.0  continuing      yes  male

# %%
df.dtypes
# Out:
# rownames        int64
# id              int64
# time            int64
# dos             int64
# hatype         object
# age             int64
# airq          float64
# medication     object
# headache       object
# sex            object
# dtype: object

# %%
print(df.describe())
pd.isna(df).any()
# Out:
#           rownames           id         time          dos          age  \
# count  4152.000000  4152.000000  4152.000000  4152.000000  4152.000000
# mean   2076.500000    66.386802    15.455684   646.705925    42.363921
# std    1198.723488    39.121812    21.737211   335.770123    11.201244
# min       1.000000     1.000000   -29.000000    98.000000    18.000000
# 25%    1038.750000    33.000000     3.000000   384.000000    33.000000
# 50%    2076.500000    67.000000    12.000000   623.000000    44.000000
# 75%    3114.250000   100.000000    24.000000   950.000000    50.000000
# max    4152.000000   133.000000    99.000000  1239.000000    66.000000
#
#               airq
# count  4152.000000
# mean     24.826012
# std       9.514274
# min       3.000000
# 25%      18.000000
# 50%      24.000000
# 75%      29.000000
# max      73.000000
# rownames      False
# id            False
# time          False
# dos           False
# hatype        False
# age           False
# ...

# %%
#Data Cleaning
df['dos'] = df['dos'].astype(str)
df['dos'].str.isnumeric().value_counts()
# Out:
# dos
# True    4152
# Name: count, dtype: int64

# %%
df['airq'].loc[df['airq'].astype(str).str.isnumeric() == False]
# Out:
# 0        9.0
# 1        7.0
# 2       10.0
# 3       13.0
# 4       18.0
#         ...
# 4147    20.0
# 4148    27.0
# 4149    28.0
# 4150    33.0
# 4151    25.0
# Name: airq, Length: 4152, dtype: float64

# %%
airq = df['airq'].loc[df['airq'] != '?']
pmean = airq.astype(int).mean()
df['airq'] = df['airq'].replace('?', pmean).astype(int)
df['airq'].head(10)
# Out:
# 0     9
# 1     7
# 2    10
# 3    13
# 4    18
# 5    19
# 6    17
# 7    21
# 8    21
# 9    18
# Name: airq, dtype: int64

# %%
airq = df['airq'].loc[df['airq'] != '?']
aqmean = airq.astype(int).mean()
df['airq'] = df['airq'].replace('?', aqmean).astype(int)
df['airq'].head()
# Out:
# 0     9
# 1     7
# 2    10
# 3    13
# 4    18
# Name: airq, dtype: int64

# %%
aq = df['airq'].loc[df['airq'] != '?']
aqmean = aq.astype(int).mean()
df['airq'] = df['airq'].replace('?', aqmean).astype(int)
df['airq'].head()
# Out:
# 0     9
# 1     7
# 2    10
# 3    13
# 4    18
# Name: airq, dtype: int64

# %%
mean = df["age"].mean()
median = df["age"].median()
mode = df["age"].mode()
print(mean, median, mode)
# Out:
# 42.363921001926784 44.0 0    46
# Name: age, dtype: int64

# %%
df['hatype'].value_counts().nlargest(30).plot(kind='bar', figsize=(10,6))
plt.title("Number of records by hatype")
plt.ylabel('Number of records')
plt.xlabel('Hatype')
plt.show()

# %%
sns.FacetGrid(df).map(sns.histplot, "age").add_legend()
plt.show()

# %%
sns.boxplot(x="age", data=df)
plt.show()

# %%
#Bivariate Analysis
import matplotlib.pyplot as plt

plt.scatter(df["age"], df["airq"])
plt.title("Scatter Plot for Age vs Air Quality")
plt.xlabel("Age")
plt.ylabel("Air Quality")
plt.show()

# %%
np.corrcoef(df["age"], df["airq"])
# Out:
# array([[ 1.        , -0.01080286],
#        [-0.01080286,  1.        ]])

# %%
sns.boxplot(x="hatype", y="airq", data=df)
plt.show()

# %%
numeric_cols = ['age', 'airq', 'dos']
df[numeric_cols] = df[numeric_cols].replace('?', np.nan).astype(float)
sns.pairplot(df, vars=numeric_cols, kind="reg")
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
numeric_cols = ['symboling', 'normalized-losses', 'wheel-base']
df[numeric_cols] = df[numeric_cols].replace('?', np.nan).astype(float)
sns.pairplot(df, vars=numeric_cols, hue="drive-wheels", height=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-557717577.py in <cell line: 0>()
#       1 sns.set(style="ticks", color_codes=True)
#       2 numeric_cols = ['symboling', 'normalized-losses', 'wheel-base']
# ----> 3 df[numeric_cols] = df[numeric_cols].replace('?', np.nan).astype(float)
#       4 sns.pairplot(df, vars=numeric_cols, hue="drive-wheels", height=2)
#       5 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, height=2, vars=['age', 'airq', 'dos'], hue='sex')
plt.show()

# %%
from scipy import stats

corr = stats.pearsonr(df["age"], df["airq"])
print("p-value:\t", corr[1])
print("correlation:\t", corr[0])
# Out:
# p-value:	 0.48648892539178623
# correlation:	 -0.010802861341161969

# %%
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#           rownames        id      time       dos       age      airq
# rownames  1.000000  0.999403 -0.131084  0.971490  0.054772 -0.105656
# id        0.999403  1.000000 -0.137080  0.971239  0.057145 -0.104299
# time     -0.131084 -0.137080  1.000000 -0.085977 -0.055781 -0.001394
# dos       0.971490  0.971239 -0.085977  1.000000  0.021148 -0.131591
# age       0.054772  0.057145 -0.055781  0.021148  1.000000 -0.010803
# airq     -0.105656 -0.104299 -0.001394 -0.131591 -0.010803  1.000000

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns)
# Out:
# <Axes: >

# %%
#Time Series Analysis

# %%
#Skipping TSA

# %%
#MODULE 4

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/KosteckiDillon.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    rownames  id  time  dos hatype  age  airq  medication headache     sex
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
# 3         4   1    -8  756   Aura   30  13.0  continuing      yes  female
# 4         5   1    -7  757   Aura   30  18.0  continuing      yes  female

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Separate numeric and categorical columns
num_cols = df.select_dtypes(include=["int64","float64"]).columns
cat_cols = df.select_dtypes(include=["object","category"]).columns

# NUMERICAL VARIABLES
print("===== NUMERICAL VARIABLES ANALYSIS =====")
desc_stats = df[num_cols].describe().T
desc_stats["range"] = desc_stats["max"] - desc_stats["min"]
desc_stats["var"] = df[num_cols].var()
desc_stats["std"] = df[num_cols].std()
desc_stats["cv"] = desc_stats["std"] / desc_stats["mean"]
desc_stats["skewness"] = df[num_cols].skew()
desc_stats["kurtosis"] = df[num_cols].kurtosis()
print(desc_stats)
# Out:
# ===== NUMERICAL VARIABLES ANALYSIS =====
#            count         mean          std   min      25%     50%      75%  \
# rownames  4152.0  2076.500000  1198.723488   1.0  1038.75  2076.5  3114.25
# id        4152.0    66.386802    39.121812   1.0    33.00    67.0   100.00
# time      4152.0    15.455684    21.737211 -29.0     3.00    12.0    24.00
# dos       4152.0   646.705925   335.770123  98.0   384.00   623.0   950.00
# age       4152.0    42.363921    11.201244  18.0    33.00    44.0    50.00
# airq      4152.0    24.826012     9.514274   3.0    18.00    24.0    29.00
#
#              max   range           var        cv  skewness  kurtosis
# rownames  4152.0  4151.0  1.436938e+06  0.577281  0.000000 -1.200000
# id         133.0   132.0  1.530516e+03  0.589301 -0.005962 -1.188096
# time        99.0   128.0  4.725063e+02  1.406422  1.114048  2.251380
# dos       1239.0  1141.0  1.127416e+05  0.519201  0.038977 -1.231304
# ...

# %%
quantiles = df[num_cols].quantile([0.05,0.25,0.5,0.75,0.95])
print("\nQuantiles:\n", quantiles)
# Out:
# Quantiles:
#        rownames     id  time     dos   age  airq
# 0.05    208.55    5.0 -16.0   145.0  23.0  12.0
# 0.25   1038.75   33.0   3.0   384.0  33.0  18.0
# 0.50   2076.50   67.0  12.0   623.0  44.0  24.0
# 0.75   3114.25  100.0  24.0   950.0  50.0  29.0
# 0.95   3944.45  127.0  54.0  1187.0  60.9  44.0

# %%
for col in num_cols:
    print(f"\nMode of {col}: {df[col].mode().values}")

    plt.figure(figsize=(14,6))
    plt.subplot(1,3,1)
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram & KDE of {col}")

    plt.subplot(1,3,2)
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")

    plt.subplot(1,3,3)
    sns.violinplot(x=df[col])
    plt.title(f"Violin Plot of {col}")

    plt.tight_layout()
    plt.show()
# Out:
# Mode of rownames: [   1    2    3 ... 4150 4151 4152]
# Mode of id: [55]
# Mode of time: [ 5 10]
# Mode of dos: [213 214 215 216 217 558 559 560 561 562 563 564]
# Mode of age: [46]
# Mode of airq: [24.8]

# %%
print("\nCATEGORICAL VARIABLES ANALYSIS")
for col in cat_cols:
    freq = df[col].value_counts()
    rel_freq = df[col].value_counts(normalize=True) * 100
    print(f"\n{col}:\nFrequency:\n{freq}\nRelative %:\n{rel_freq}")
    print(f"Mode of {col}: {df[col].mode().values}")

    plt.figure(figsize=(6,4))
    sns.countplot(x=col, data=df, order=freq.index, palette="viridis")
    plt.title(f"Barplot of {col}")
    plt.show()

    plt.figure(figsize=(5,5))
    freq.plot(kind="pie", autopct='%1.1f%%')
    plt.title(f"Pie chart of {col}")
    plt.ylabel("")
    plt.show()
# Out:
# CATEGORICAL VARIABLES ANALYSIS
#
# hatype:
# Frequency:
# hatype
# No Aura    1985
# Aura       1710
# Mixed       457
# Name: count, dtype: int64
# Relative %:
# hatype
# No Aura    47.808285
# Aura       41.184971
# Mixed      11.006744
# Name: proportion, dtype: float64
# Mode of hatype: ['No Aura']
# /tmp/ipython-input-52561506.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, order=freq.index, palette="viridis")
# medication:
# Frequency:
# medication
# continuing    2386
# reduced        981
# none           785
# Name: count, dtype: int64
# Relative %:
# medication
# continuing    57.466281
# reduced       23.627168
# none          18.906551
# Name: proportion, dtype: float64
# Mode of medication: ['continuing']
# /tmp/ipython-input-52561506.py:9: FutureWarning:
#
# ...

# %%
#2D ANALYSIS

# %%
from scipy.stats import chi2_contingency

# Separate columns
num_cols = df.select_dtypes(include=["int64","float64"]).columns
cat_cols = df.select_dtypes(include=["object","category"]).columns


print("\n NUMERICAL vs NUMERICAL ")
print("\nCorrelation Matrix:\n", df[num_cols].corr())

plt.figure(figsize=(8,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

sns.pairplot(df[num_cols])
plt.suptitle("Pairplot of Numerical Variables", y=1.02)
plt.show()
# Out:
#  NUMERICAL vs NUMERICAL
#
# Correlation Matrix:
#            rownames        id      time       dos       age      airq
# rownames  1.000000  0.999403 -0.131084  0.971490  0.054772 -0.103562
# id        0.999403  1.000000 -0.137080  0.971239  0.057145 -0.102202
# time     -0.131084 -0.137080  1.000000 -0.085977 -0.055781 -0.002529
# dos       0.971490  0.971239 -0.085977  1.000000  0.021148 -0.129934
# age       0.054772  0.057145 -0.055781  0.021148  1.000000 -0.009163
# airq     -0.103562 -0.102202 -0.002529 -0.129934 -0.009163  1.000000

# %%
sns.pairplot(df[num_cols])
plt.suptitle("Pairplot of Numerical Variables", y=1.02)
plt.show()

for i in range(len(num_cols)):
    for j in range(i+1, len(num_cols)):
        plt.figure(figsize=(6,4))
        sns.scatterplot(x=df[num_cols[i]], y=df[num_cols[j]])
        sns.regplot(x=df[num_cols[i]], y=df[num_cols[j]], scatter=False, color="red")
        plt.title(f"{num_cols[i]} vs {num_cols[j]}")
        plt.show()

# %%
print("\n NUMERICAL vs CATEGORICAL ")
for num in num_cols:
    for cat in cat_cols:
        print(f"\nGroup statistics for {num} by {cat}:")
        print(df.groupby(cat)[num].describe())

        plt.figure(figsize=(8,5))
        sns.boxplot(x=cat, y=num, data=df)
        plt.title(f"Boxplot of {num} by {cat}")
        plt.show()

        plt.figure(figsize=(8,5))
        sns.violinplot(x=cat, y=num, data=df)
        plt.title(f"Violin Plot of {num} by {cat}")
        plt.show()
# Out:
#  NUMERICAL vs CATEGORICAL
#
# Group statistics for rownames by hatype:
#           count         mean          std     min      25%     50%      75%  \
# hatype
# Aura     1710.0  1668.453216  1138.443140     1.0   428.25  1632.5  2576.75
# Mixed     457.0  3214.571116   998.310380  1155.0  3286.00  3552.0  3913.00
# No Aura  1985.0  2166.002015  1100.491596   458.0  1208.00  2061.0  3120.00
#
#             max
# hatype
# Aura     4152.0
# Mixed    4109.0
# No Aura  4129.0
# Group statistics for rownames by medication:
#              count         mean          std    min      25%     50%      75%  \
# medication
# continuing  2386.0  2142.128248  1262.725482    1.0  1011.25  2374.5  3182.75
# none         785.0  2246.523567  1138.339213  486.0  1452.00  2302.0  3465.00
# reduced      981.0  1780.824669  1023.824891  169.0   924.00  1686.0  2610.00
#
#                max
# medication
# continuing  4152.0
# none        3930.0
# reduced     4004.0
# ...

# %%
print("\nCATEGORICAL vs CATEGORICAL")
for i in range(len(cat_cols)):
    for j in range(i+1, len(cat_cols)):
        print(f"\nContingency table: {cat_cols[i]} vs {cat_cols[j]}")
        crosstab = pd.crosstab(df[cat_cols[i]], df[cat_cols[j]])
        print(crosstab)

        chi2, p, dof, expected = chi2_contingency(crosstab)
        print(f"Chi-Square Test: chi2={chi2:.2f}, p-value={p:.4f}, dof={dof}")

        plt.figure(figsize=(6,4))
        crosstab.plot(kind="bar", stacked=True)
        plt.title(f"Stacked Barplot: {cat_cols[i]} vs {cat_cols[j]}")
        plt.xlabel(cat_cols[i])
        plt.ylabel("Count")
        plt.show()

        plt.figure(figsize=(6,4))
        sns.heatmap(crosstab, annot=True, fmt="d", cmap="YlGnBu")
        plt.title(f"Heatmap of {cat_cols[i]} vs {cat_cols[j]}")
        plt.show()
# Out:
# CATEGORICAL vs CATEGORICAL
#
# Contingency table: hatype vs medication
# medication  continuing  none  reduced
# hatype
# Aura              1079   354      277
# Mixed              194   113      150
# No Aura           1113   318      554
# Chi-Square Test: chi2=119.59, p-value=0.0000, dof=4
# Contingency table: hatype vs headache
# headache   no   yes
# hatype
# Aura      581  1129
# Mixed      96   361
# No Aura   809  1176
# Chi-Square Test: chi2=67.21, p-value=0.0000, dof=2
# Contingency table: hatype vs sex
# sex      female  male
# hatype
# Aura       1593   117
# Mixed       291   166
# No Aura    1661   324
# Chi-Square Test: chi2=259.95, p-value=0.0000, dof=2
# Contingency table: medication vs headache
# headache     no   yes
# medication
# continuing  825  1561
# none        440   345
# reduced     221   760
# Chi-Square Test: chi2=216.83, p-value=0.0000, dof=2
# Contingency table: medication vs sex
# sex         female  male
# medication
# continuing    2156   230
# ...

# %%
#3D ANALYSIS

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np


print("\n 3D Scatter PloT ")
if len(num_cols) >= 3:
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(df[num_cols[0]], df[num_cols[1]], df[num_cols[2]], c='blue', alpha=0.6)
    ax.set_xlabel(num_cols[0])
    ax.set_ylabel(num_cols[1])
    ax.set_zlabel(num_cols[2])
    plt.title(f"3D Scatter: {num_cols[0]} vs {num_cols[1]} vs {num_cols[2]}")
    plt.show()
# Out:
#  3D Scatter PloT

# %%
print("\n3D Box Plot (Faceted) ")
if len(cat_cols) >= 2 and len(num_cols) >= 1:
    for num in num_cols[:2]:
        plt.figure(figsize=(10,6))
        sns.catplot(x=cat_cols[0], y=num, hue=cat_cols[1], kind="box", data=df, height=6, aspect=1.5)
        plt.title(f"3D Boxplot of {num} by {cat_cols[0]} and {cat_cols[1]}")
        plt.show()
# Out:
# 3D Box Plot (Faceted)

# %%
print("\n Radar Chart (Profile of numerical variables) ")
def make_radar_chart(row, num_vars, title):
    categories = list(num_vars)
    values = row[num_vars].values.flatten().tolist()
    values += values[:1]  # close circle

    angles = np.linspace(0, 2*np.pi, len(categories), endpoint=False).tolist()
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(polar=True))
    ax.plot(angles, values, linewidth=2)
    ax.fill(angles, values, alpha=0.25)
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    plt.title(title)
    plt.show()
# Out:
#  Radar Chart (Profile of numerical variables)

# %%
for i in range(3):
    make_radar_chart(df.iloc[i], num_cols[:5], title=f"Radar Profile - Row {i+1}")


print("\n 3D Heatmap (Categorical combinations vs Numeric Mean)")
if len(cat_cols) >= 2 and len(num_cols) >= 1:
    pivot_table = df.pivot_table(index=cat_cols[0], columns=cat_cols[1], values=num_cols[0], aggfunc="mean")
    sns.heatmap(pivot_table, annot=True, cmap="coolwarm")
    plt.title(f"Heatmap of {num_cols[0]} across {cat_cols[0]} and {cat_cols[1]}")
    plt.show()
# Out:
#  3D Heatmap (Categorical combinations vs Numeric Mean)

# %%
#MODULE 5

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Select numerical features for clustering
num_df = df.select_dtypes(include=['int64', 'float64']).dropna()

# Standardize features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(num_df)

# Apply KMeans with 3 clusters (you can change k)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(scaled_data)

# Add cluster labels to dataframe
df['Cluster'] = clusters

# Plot clusters using first two features
plt.figure(figsize=(8,6))
plt.scatter(scaled_data[:,0], scaled_data[:,1], c=clusters, cmap='viridis', s=50)
plt.xlabel(num_df.columns[0])
plt.ylabel(num_df.columns[1])
plt.title("K-Means Clustering (k=3)")
plt.show()

# Cluster centers (in original scale)
centers = scaler.inverse_transform(kmeans.cluster_centers_)
print("Cluster Centers (original scale):")
print(pd.DataFrame(centers, columns=num_df.columns))
# Out:
# Cluster Centers (original scale):
#       rownames          id       time         dos        age       airq
# 0   736.148913   22.468478  27.354348  294.209783  32.179348  23.903043
# 1  3246.821963  104.261786  12.181919  976.170826  42.163616  23.349418
# 2  1462.806858   46.874038  11.925822  457.952414  49.173548  27.283275

# %%
#PHASE 3

# %%
#Dimensionality reduction - PCA

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/KosteckiDillon.csv"
df = pd.read_csv(url)

print(" Dataset loaded successfully!\n")
print(df.head())
print("\nDataset shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())

label_enc = LabelEncoder()
for col in df.select_dtypes(include=['object']).columns:
    df[col] = label_enc.fit_transform(df[col])

print("\n Categorical variables encoded successfully!")
print(df.head())

X = df.drop("headache", axis=1)
y = df["headache"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("\n PCA completed successfully!")
print("Explained variance ratio:", pca.explained_variance_ratio_)

plt.figure(figsize=(8,5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title("PCA - Visualization of Data (2D Projection)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar(label="Headache (0 = No, 1 = Yes)")
plt.show()

X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("\n Model Evaluation Results:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix - Random Forest Classifier")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
#  Dataset loaded successfully!
#
#    rownames  id  time  dos hatype  age  airq  medication headache     sex
# 0         1   1   -11  753   Aura   30   9.0  continuing      yes  female
# 1         2   1   -10  754   Aura   30   7.0  continuing      yes  female
# 2         3   1    -9  755   Aura   30  10.0  continuing      yes  female
# 3         4   1    -8  756   Aura   30  13.0  continuing      yes  female
# 4         5   1    -7  757   Aura   30  18.0  continuing      yes  female
#
# Dataset shape: (4152, 10)
#
# Missing values:
#  rownames      0
# id            0
# time          0
# dos           0
# hatype        0
# age           0
# airq          0
# medication    0
# headache      0
# sex           0
# dtype: int64
#
#  Categorical variables encoded successfully!
#    rownames  id  time  dos  hatype  age  airq  medication  headache  sex
# 0         1   1   -11  753       0   30   9.0           0         1    0
# ...

# %%
#Model building and - Regression or Classification

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/KosteckiDillon.csv"
df = pd.read_csv(url)

label_enc = LabelEncoder()
for col in df.select_dtypes(include=['object']).columns:
    df[col] = label_enc.fit_transform(df[col])

X = df.drop(["headache","airq"], axis=1)
y_class = df["headache"]
y_reg = df["airq"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(X_pca, y_class, test_size=0.2, random_state=42)
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_c, y_train_c)
y_pred_c = clf.predict(X_test_c)

print("CLASSIFICATION RESULTS\n")
print("Accuracy:", accuracy_score(y_test_c, y_pred_c))
print("\nConfusion Matrix:\n", confusion_matrix(y_test_c, y_pred_c))
print("\nClassification Report:\n", classification_report(y_test_c, y_pred_c))

plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix(y_test_c, y_pred_c), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix - Classification")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X_pca, y_reg, test_size=0.2, random_state=42)
reg = RandomForestRegressor(random_state=42)
reg.fit(X_train_r, y_train_r)
y_pred_r = reg.predict(X_test_r)

print("\nREGRESSION RESULTS\n")
print("MAE:", mean_absolute_error(y_test_r, y_pred_r))
print("MSE:", mean_squared_error(y_test_r, y_pred_r))
print("RMSE:", np.sqrt(mean_squared_error(y_test_r, y_pred_r)))
print("R² Score:", r2_score(y_test_r, y_pred_r))

plt.figure(figsize=(6,4))
plt.scatter(y_test_r, y_pred_r, alpha=0.7)
plt.title("Actual vs Predicted - Regression")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()
# Out:
# CLASSIFICATION RESULTS
#
# Accuracy: 0.7496991576413959
#
# Confusion Matrix:
#  [[154 127]
#  [ 81 469]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.55      0.60       281
#            1       0.79      0.85      0.82       550
#
#     accuracy                           0.75       831
#    macro avg       0.72      0.70      0.71       831
# weighted avg       0.74      0.75      0.74       831
# REGRESSION RESULTS
#
# MAE: 5.416714801444044
# MSE: 56.86981170156439
# RMSE: 7.54120757581731
# R² Score: 0.3497335768768126
